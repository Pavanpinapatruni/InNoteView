# %%
from innoteview import render_site

# %%
render_site("https://docs.python.org")
# Out:
# [2026-02-20 11:22:48] INFO - innoteview.site - Rendering site → https://docs.python.org (width=1024, height=600)
#         <iframe
#             width="1024"
#             height="600"
#             src="https://docs.python.org"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from innoteview import render_youtube_video

# %%
render_youtube_video("https://youtu.be/lSvo9mRrTHY?si=vEuwMfK_3VeGUxpT")
# Out:
# [2026-02-20 11:24:24] DEBUG - innoteview.youtube - Extracted video ID: lSvo9mRrTHY from URL: https://youtu.be/lSvo9mRrTHY?si=vEuwMfK_3VeGUxpT
# [2026-02-20 11:24:24] INFO - innoteview.youtube - Rendering YouTube video → ID: lSvo9mRrTHY (width=800, height=450)
#         <iframe
#             width="800"
#             height="450"
#             src="https://www.youtube.com/embed/lSvo9mRrTHY"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from innoteview import render_site

# %%
try:
    render_site("http://not-https.com")
except Exception as e:
    print(f"Error type: {type(e).__name__}")
    print(f"Error message: {e}")
# Out:
# [2026-02-20 11:27:02] ERROR - innoteview.site - Invalid URL provided: http://not-https.com
# Error type: InvalidURLError
# Error message: Invalid URL provided: 'http://not-https.com'. Only HTTPS URLs are supported. Please provide a URL starting with 'https://'

# %%
import innoteview
print(f"InNoteView v{innoteview.__version__})
# Out:
#   Cell In[8], line 2
#     print(f"InNoteView v{innoteview.__version__})
#                                                  ^
# SyntaxError: EOL while scanning string literal
